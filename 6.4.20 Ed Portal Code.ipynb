# %%
# Code from last time
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("Boston weather_clean.csv")
dewpoint = data["Avg Dew Point (F)"]
temp = data["Avg Temp (F)"]

plt.scatter(dewpoint, temp)
plt.show()

x = np.linspace(-20, 80)
# change up numbers here until it seems like it works visually
y = np.multiply(x, .9) + 20

plt.plot(x, y, "r")
plt.show()

plt.plot(x, y, "r")
plt.scatter(dewpoint, temp)
plt.show()

# Actually trying out the predictions

print(dewpoint[400]*0.9 + 20)
print(temp[400])
# Out:
# 28.1
# 20

# %%
# creating new columns: simply define them!

# before you run this: what do you think that this code does?
data["year2"] = data["Year"]
data
# Out:
#       Year  Month  Day  High Temp (F)  Avg Temp (F)  Low Temp (F)  \
# 0     2008      1    1             40            34            28
# 1     2008      1    2             33            22            10
# 2     2008      1    3             14            11             7
# 3     2008      1    4             32            20             8
# 4     2008      1    5             42            35            27
# 5     2008      1    6             47            42            36
# 6     2008      1    7             55            45            35
# 7     2008      1    8             67            56            45
# 8     2008      1    9             62            54            46
# 9     2008      1   10             49            44            38
# 10    2008      1   11             57            48            38
# 11    2008      1   12             48            43            38
# 12    2008      1   13             44            37            30
# ...

# %%
# you can also create new columns with mathematical operations

data["year2"] = data["Year"]*2

data
# notice what this does to each value in the year column

# Question: Where did the data from the previous year2 column go?
# Out:
#       Year  Month  Day  High Temp (F)  Avg Temp (F)  Low Temp (F)  \
# 0     2008      1    1             40            34            28
# 1     2008      1    2             33            22            10
# 2     2008      1    3             14            11             7
# 3     2008      1    4             32            20             8
# 4     2008      1    5             42            35            27
# 5     2008      1    6             47            42            36
# 6     2008      1    7             55            45            35
# 7     2008      1    8             67            56            45
# 8     2008      1    9             62            54            46
# 9     2008      1   10             49            44            38
# 10    2008      1   11             57            48            38
# 11    2008      1   12             48            43            38
# 12    2008      1   13             44            37            30
# ...

# %%
# Step 1: Define a column to represent your temperature prediction

data["Predicted Temp"] = data["Avg Dew Point (F)"]*? + ?
data

# %%
# Step 2: Create a column for the difference between prediction and real value
# Hint: Start by thinking about what values we have to subtract
data["Prediction Error"] = ?

data

# %%
# Step 3: Sorting to find our best predictions
# Hint: the code to sort a dataframe is pd.sort_values(by = "Column Name")

# %%
# Step 4: How will we assess our predictions overall? 
# 2 hints: 1) How could we graph this? 2) Think about absolute value

# Code for plotting goes here
plt.show()

# %% [markdown]
# ### (If we have time) Regression: A better method for determining the relationship
#
# - The line that we drew was arbitrary
# - If you use Excel or other programs to find a trendline or line of best fit, they'll spit out a particular line; how do they determine this line?
# - Regression analysis is applied in basically every field; it's super important

# %% [markdown]
# - Regression is about explanation: the independent variable (x) is sometimes called the explanatory variable and the dependent variable is sometimes called the response variable
# - The goal is to look at how x explains y
# - R^2
